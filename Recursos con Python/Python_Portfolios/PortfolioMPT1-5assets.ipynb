# %% [markdown]
# # Universidad Nacional de Ingeniería #
# ## Facultad de Ingeniería Económica, Estadística y CC.SS
# ### Finanzas Corporativas II - 2021-I
# #### Teoría de Portafolio
#
# Docente: Alfonso Chang Medina MSc \\
# Fecha: Abril~Mayo 2021 \\
# e-mail: achangm@uni.edu.pe

# %% [markdown]
# Trabajaremos portafolios de **5 activos**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
daily_returns = pd.read_csv("Returns.csv", index_col ="Date")
daily_returns
# Out:
#                 ABOT      ACPL      ADMM      AGIL    AGTL
# Date
# 01/01/2015 -0.013902  0.050010  0.009142  0.001501 -0.0058
# 01/02/2015  0.033034  0.027779  0.011769  0.032827 -0.0046
# 01/05/2015 -0.009752  0.002904 -0.031203  0.044773 -0.0051
# 01/06/2015 -0.023324 -0.003494  0.006421  0.047703  0.0487
# 01/07/2015  0.001902  0.024085 -0.012817  0.001301  0.0487
# ...              ...       ...       ...       ...     ...
# 22/12/2017  0.030248  0.049905  0.000000  0.050115  0.0298
# 26/12/2017  0.040499  0.043416  0.000000 -0.002397 -0.0114
# 27/12/2017 -0.048485  0.008435  0.000000 -0.029360  0.0125
# 28/12/2017  0.017451  0.032414  0.000000  0.000000  0.0208
# 29/12/2017 -0.002696 -0.021662  0.000000 -0.007174 -0.0136
#
# [744 rows x 5 columns]

# %%
mean_ret = daily_returns.mean()
mean_ret
# Out:
# ABOT    0.000263
# ACPL    0.000359
# ADMM   -0.000338
# AGIL    0.001378
# AGTL    0.001262
# dtype: float64

# %%
#Generating a random matrix of 1000 rows and 4 Columns
matrix = np.random.rand(1000,5)
matrix
# Out:
# array([[0.03793399, 0.23162727, 0.4241891 , 0.61955104, 0.83181821],
#        [0.85811623, 0.14620567, 0.79904689, 0.07597934, 0.09784391],
#        [0.34839287, 0.62540084, 0.38155596, 0.47263642, 0.18345699],
#        ...,
#        [0.69845057, 0.31934102, 0.97262582, 0.11369351, 0.54769691],
#        [0.73501671, 0.24603666, 0.69369365, 0.10872861, 0.11521956],
#        [0.19196068, 0.05529799, 0.05339183, 0.12752771, 0.30489702]])

# %%
#Converting to a data frame
matrix_df = pd.DataFrame(matrix, columns = daily_returns.columns)
matrix_df
# Out:
#          ABOT      ACPL      ADMM      AGIL      AGTL
# 0    0.037934  0.231627  0.424189  0.619551  0.831818
# 1    0.858116  0.146206  0.799047  0.075979  0.097844
# 2    0.348393  0.625401  0.381556  0.472636  0.183457
# 3    0.621090  0.399250  0.101075  0.673702  0.214933
# 4    0.389246  0.011894  0.394807  0.639794  0.470837
# ..        ...       ...       ...       ...       ...
# 995  0.389778  0.781210  0.297267  0.503297  0.822846
# 996  0.196934  0.083022  0.583718  0.026723  0.607528
# 997  0.698451  0.319341  0.972626  0.113694  0.547697
# 998  0.735017  0.246037  0.693694  0.108729  0.115220
# 999  0.191961  0.055298  0.053392  0.127528  0.304897
#
# [1000 rows x 5 columns]

# %%
matrix_sum = matrix_df.sum(axis = 1)
matrix_sum
# Out:
# 0      2.145120
# 1      1.977192
# 2      2.011443
# 3      2.010051
# 4      1.906579
#          ...
# 995    2.794397
# 996    1.497924
# 997    2.651808
# 998    1.898695
# 999    0.733075
# Length: 1000, dtype: float64

# %%
#Calculating portfolio weights
weights  = matrix_df.divide(matrix_sum , axis ="rows")
weights
# Out:
#          ABOT      ACPL      ADMM      AGIL      AGTL
# 0    0.017684  0.107979  0.197746  0.288819  0.387772
# 1    0.434008  0.073946  0.404132  0.038428  0.049486
# 2    0.173205  0.310921  0.189693  0.234974  0.091207
# 3    0.308992  0.198627  0.050285  0.335167  0.106929
# 4    0.204159  0.006238  0.207076  0.335572  0.246954
# ..        ...       ...       ...       ...       ...
# 995  0.139485  0.279563  0.106380  0.180109  0.294463
# 996  0.131471  0.055425  0.389685  0.017840  0.405580
# 997  0.263387  0.120424  0.366778  0.042874  0.206537
# 998  0.387117  0.129582  0.365353  0.057265  0.060684
# 999  0.261857  0.075433  0.072833  0.173963  0.415915
#
# [1000 rows x 5 columns]

# %%
#transpose
weights_t= np.transpose(weights)
weights_t
# Out:
#            0         1         2         3         4         5         6    \
# ABOT  0.017684  0.434008  0.173205  0.308992  0.204159  0.141918  0.285772
# ACPL  0.107979  0.073946  0.310921  0.198627  0.006238  0.131903  0.235093
# ADMM  0.197746  0.404132  0.189693  0.050285  0.207076  0.183922  0.142948
# AGIL  0.288819  0.038428  0.234974  0.335167  0.335572  0.371883  0.183002
# AGTL  0.387772  0.049486  0.091207  0.106929  0.246954  0.170374  0.153185
#
#            7         8         9    ...       990       991       992  \
# ABOT  0.218730  0.308817  0.343410  ...  0.244592  0.329424  0.173324
# ACPL  0.217361  0.291821  0.135711  ...  0.113687  0.342680  0.128191
# ADMM  0.016227  0.142498  0.089641  ...  0.386211  0.011063  0.184259
# AGIL  0.278007  0.075738  0.307294  ...  0.199886  0.208108  0.153529
# AGTL  0.269676  0.181127  0.123944  ...  0.055625  0.108726  0.360697
#
#            993       994       995       996       997       998       999
# ABOT  0.051238  0.105073  0.139485  0.131471  0.263387  0.387117  0.261857
# ACPL  0.265209  0.229748  0.279563  0.055425  0.120424  0.129582  0.075433
# ADMM  0.488065  0.261550  0.106380  0.389685  0.366778  0.365353  0.072833
# AGIL  0.189359  0.297586  0.180109  0.017840  0.042874  0.057265  0.173963
# AGTL  0.006128  0.106044  0.294463  0.405580  0.206537  0.060684  0.415915
#
# [5 rows x 1000 columns]

# %%
#Using the portfolio return formula
portfolio_return = np.dot(weights, mean_ret)
portfolio_return
# Out:
# array([8.63880688e-04, 1.19453957e-04, 5.31992618e-04, 7.32266955e-04,
#        7.59890036e-04, 7.49932154e-04, 5.56674424e-04, 8.53373102e-04,
#        4.70716921e-04, 6.88470182e-04, 5.88203929e-04, 7.80654322e-04,
#        6.82019906e-04, 7.04351205e-04, 5.53708287e-04, 4.34050210e-04,
#        4.52063472e-04, 4.43736914e-04, 5.85272269e-04, 5.08766290e-04,
#        4.29732280e-04, 7.79856455e-04, 7.19400624e-04, 7.30839079e-04,
#        7.40880586e-04, 6.62073555e-04, 8.66044558e-04, 7.38499317e-04,
#        6.31584074e-04, 3.39144881e-04, 3.32401573e-04, 4.31993908e-04,
#        5.20041217e-04, 8.60848504e-04, 6.12869911e-04, 5.73190669e-04,
#        6.26439412e-04, 8.59594497e-04, 9.04807633e-04, 5.94324582e-04,
#        8.45147568e-04, 6.02653859e-04, 2.50824043e-04, 3.56854404e-04,
#        4.61382186e-04, 4.07963855e-04, 5.60276824e-04, 4.36613026e-04,
#        4.58456022e-04, 8.28907488e-04, 5.24799204e-04, 6.87350730e-04,
#        4.47925114e-04, 1.00857612e-03, 3.07552083e-04, 5.10932214e-04,
#        5.31758913e-04, 7.23375656e-04, 4.26362130e-04, 5.75490181e-04,
#        5.59703492e-04, 2.06944268e-04, 5.02650409e-04, 4.52267000e-04,
#        2.66381286e-04, 4.33776246e-04, 7.79845854e-04, 4.61369180e-04,
#        4.51265701e-04, 5.23390109e-04, 4.11157139e-04, 6.04812994e-04,
#        5.70565721e-04, 6.38227089e-04, 7.33025439e-04, 6.73524296e-04,
#        4.55450358e-04, 7.07234119e-04, 9.79874833e-04, 4.28666843e-04,
#        5.29973009e-04, 5.73434212e-04, 6.87478151e-04, 5.05005614e-04,
#        5.67760416e-04, 4.43710578e-04, 7.75619360e-04, 6.60183226e-04,
#        5.85842014e-04, 6.85181807e-04, 4.02936950e-04, 5.48304734e-04,
#        8.64351737e-04, 5.59249772e-04, 8.82852696e-04, 8.66344990e-04,
#        6.27243383e-04, 6.48377661e-04, 1.03570882e-03, 7.20123575e-04,
#        5.84716843e-04, 4.19314971e-04, 5.02744091e-04, 7.45361559e-04,
#        4.65568997e-04, 9.25489638e-04, 6.02884449e-04, 6.01620883e-04,
#        4.76433663e-04, 7.60637810e-04, 6.20431540e-04, 7.23544415e-04,
#        4.01469983e-04, 6.00056140e-04, 5.40018373e-04, 7.99857632e-04,
#        6.49626419e-04, 4.98557744e-04, 6.24383513e-04, 6.70982230e-04,
#        5.36825698e-04, 6.05156536e-04, 6.41724871e-04, 3.10640491e-04,
#        4.31226127e-04, 6.72590856e-04, 5.08987770e-04, 4.47890496e-04,
#        6.24439315e-04, 6.94513940e-04, 4.48430613e-04, 4.77056264e-04,
#        7.63863314e-04, 4.55572157e-04, 1.77563675e-04, 8.02726378e-04,
#        4.24666942e-04, 4.88384267e-04, 5.45330818e-04, 7.43948587e-04,
#        5.62447426e-04, 4.78736594e-04, 5.18525972e-04, 3.47748225e-04,
#        8.17429197e-04, 5.38554424e-04, 6.15395678e-04, 4.86197506e-04,
#        6.02142610e-04, 3.11768780e-04, 5.86339393e-04, 5.08013258e-04,
#        2.52513223e-04, 6.76927302e-04, 6.48021820e-04, 7.89568116e-04,
#        7.44397337e-04, 7.85450578e-04, 2.30044664e-04, 4.21109477e-04,
#        5.63553203e-04, 4.02788877e-04, 6.33337206e-04, 3.23727476e-04,
#        5.60222954e-04, 2.50253879e-04, 8.96644377e-04, 7.98513281e-04,
#        3.79731959e-04, 4.38121296e-04, 4.82856293e-04, 5.79351614e-04,
#        6.65848614e-04, 3.78731863e-04, 4.84499030e-04, 4.28128306e-04,
#        4.49808906e-04, 2.90416198e-04, 5.67473984e-04, 6.42030455e-04,
#        5.96389818e-04, 6.31984207e-04, 4.91933412e-04, 9.79105289e-04,
#        7.44060859e-04, 5.32832305e-04, 3.93603708e-04, 8.10413709e-04,
#        7.58977480e-04, 4.96466740e-04, 7.60866891e-04, 2.68956156e-04,
#        7.16298599e-04, 3.78506767e-05, 5.79240029e-04, 3.88141749e-04,
#        7.57006225e-04, 8.25948640e-04, 6.98539394e-04, 8.18189564e-04,
#        6.70538748e-04, 6.65670535e-04, 4.61771224e-04, 4.22119753e-04,
#        8.37093901e-04, 4.64735473e-04, 6.30792841e-04, 5.93059163e-04,
#        3.40395327e-04, 5.76409383e-04, 6.41164429e-04, 3.52772563e-04,
#        5.94092564e-04, 7.59623194e-04, 5.54834090e-04, 5.62871614e-04,
#        7.21859214e-04, 7.24141100e-04, 6.74480725e-04, 7.51231849e-04,
#        4.15327359e-04, 7.68988804e-04, 4.49492226e-04, 5.78304239e-04,
#        9.90032331e-04, 4.36547967e-04, 6.09087327e-04, 6.22012444e-04,
#        4.63186679e-04, 2.13388431e-04, 5.03047225e-04, 8.18310825e-04,
#        6.20267409e-04, 5.37759784e-04, 6.25861343e-04, 8.55960322e-04,
#        3.63871687e-04, 5.07356207e-04, 6.33255774e-04, 5.97238986e-04,
#        5.94359879e-04, 6.15171625e-04, 5.49703533e-04, 4.84329423e-04,
#        4.53769481e-04, 6.20389005e-04, 7.58396580e-04, 3.67503499e-04,
#        4.66541167e-04, 2.42014341e-04, 7.32819286e-04, 5.56425682e-04,
#        7.86484973e-04, 6.09236070e-04, 3.96553540e-04, 8.58641247e-04,
#        7.10277897e-04, 7.99834527e-04, 6.94804790e-04, 6.37046540e-04,
#        7.03428796e-04, 7.14130421e-04, 6.61142303e-04, 4.98350948e-04,
#        6.97899011e-04, 5.18921899e-04, 3.27089788e-04, 8.49558800e-04,
#        5.44960384e-04, 4.78369743e-04, 8.27456446e-04, 5.05868051e-04,
#        6.10826074e-04, 9.53096905e-04, 8.27778781e-04, 9.04080288e-04,
#        2.49388366e-04, 2.75900843e-04, 7.18331692e-04, 5.70822148e-04,
#        1.86566930e-04, 7.16197958e-04, 5.74560370e-04, 8.15495913e-04,
#        9.42435395e-04, 4.82358264e-04, 6.52181528e-04, 4.40050836e-04,
#        5.78244729e-04, 5.02320625e-04, 6.52070459e-04, 4.60814615e-04,
#        6.26309614e-04, 3.52520150e-04, 6.98088123e-04, 4.57892308e-04,
#        4.99075250e-04, 6.30598307e-04, 3.29848203e-04, 7.97401488e-04,
#        9.42446559e-04, 6.21314494e-04, 5.04176743e-04, 3.59542988e-04,
#        2.96168736e-04, 5.57817116e-04, 1.67219951e-04, 5.25863395e-04,
#        5.16264651e-04, 7.97536837e-04, 6.83783120e-04, 1.77846878e-04,
#        6.72030080e-04, 3.38173170e-04, 4.12724600e-04, 3.66390302e-04,
#        3.55632367e-04, 5.34601352e-04, 8.49543530e-04, 7.15955484e-05,
#        8.67117515e-04, 7.63538293e-04, 6.28408289e-04, 6.02703395e-04,
#        3.85084302e-04, 5.87004865e-04, 4.15168668e-04, 7.86781758e-04,
#        4.08842532e-04, 6.25295925e-04, 4.85678283e-04, 5.55191115e-04,
#        7.86251564e-04, 7.11285934e-04, 6.69983428e-04, 7.53191687e-04,
#        6.23355921e-04, 6.14603702e-04, 6.41828939e-04, 3.81469137e-04,
#        6.24319045e-04, 8.89623827e-04, 5.19427201e-04, 2.59140048e-04,
#        7.04929822e-04, 5.59709377e-04, 3.95670745e-04, 3.83455447e-04,
#        5.15684858e-04, 7.47865761e-04, 5.63449762e-04, 5.29774001e-04,
#        1.16680521e-03, 6.04221462e-04, 4.10004447e-04, 7.89162334e-04,
#        3.99860517e-04, 4.20038614e-04, 5.89579860e-04, 7.46062162e-04,
#        5.45163789e-04, 3.76732245e-04, 3.68183572e-04, 6.92558790e-04,
#        5.68620739e-04, 4.53843448e-04, 4.27844572e-04, 6.16538779e-04,
#        2.98402453e-04, 5.39418112e-04, 6.51325423e-04, 4.84101082e-04,
#        5.05623088e-04, 5.24582134e-04, 5.26241906e-04, 5.16791015e-04,
#        9.59784409e-04, 7.28060672e-04, 5.12958307e-04, 3.25245739e-04,
#        9.35379715e-04, 4.45738467e-04, 6.52265697e-04, 4.64424248e-04,
#        3.67649605e-04, 5.01264264e-04, 6.37884114e-04, 7.91104514e-04,
#        6.03452946e-04, 6.89737944e-04, 7.38405422e-04, 6.64167983e-04,
#        5.73213704e-04, 7.85647593e-04, 4.55755772e-04, 4.00955281e-04,
#        9.17963392e-04, 8.45253291e-04, 9.97297928e-04, 6.45505280e-04,
#        8.11718569e-04, 2.62693813e-04, 3.83399616e-04, 3.73431204e-04,
#        6.29159875e-04, 4.22232466e-04, 7.17281139e-04, 3.68131290e-04,
#        7.71964788e-04, 4.88813990e-04, 3.08142242e-04, 7.26672336e-04,
#        3.52133533e-04, 6.35653747e-04, 2.96549388e-04, 9.11371475e-04,
#        4.21537873e-04, 5.45660477e-04, 6.08733312e-04, 5.09314932e-05,
#        3.99651610e-04, 8.40777548e-04, 4.68301609e-04, 7.70913221e-04,
#        8.55576655e-04, 6.56185482e-04, 6.54352505e-04, 5.23515179e-04,
#        7.68633705e-04, 1.02451818e-03, 1.01832605e-04, 7.36828414e-04,
#        8.50786449e-04, 8.19616163e-04, 8.21448182e-04, 5.62334775e-04,
#        6.55932525e-04, 6.49326421e-04, 6.73125519e-04, 7.11394495e-04,
#        4.53340971e-04, 3.24109220e-04, 6.92031904e-04, 7.17455679e-04,
#        5.63831456e-04, 5.84502136e-04, 5.19390627e-04, 4.05420746e-04,
#        2.59964511e-04, 5.36276773e-04, 5.42467887e-04, 2.76146242e-04,
#        7.30612680e-04, 3.55585854e-04, 7.53407241e-04, 4.78423015e-04,
#        6.63071452e-04, 6.03591581e-04, 5.40180725e-04, 7.78995510e-04,
#        4.68105607e-04, 2.75560726e-04, 6.96861736e-04, 6.01377251e-04,
#        5.70996009e-04, 9.80796108e-04, 5.04241250e-04, 3.48158347e-04,
#        6.01365296e-04, 6.22292587e-04, 5.21196304e-04, 6.22444600e-04,
#        4.40623159e-04, 5.20142965e-04, 4.06168066e-04, 4.40718115e-04,
#        7.89007319e-04, 6.81883531e-04, 8.78414084e-04, 8.56375597e-04,
#        9.43640060e-04, 4.06403888e-04, 1.97021013e-04, 5.42025566e-04,
#        7.47565793e-04, 4.00883883e-04, 7.35937232e-04, 3.18767346e-04,
#        7.44291528e-04, 6.33266974e-04, 4.62794039e-04, 6.79926324e-04,
#        6.04625179e-04, 4.93350752e-04, 5.48652373e-04, 5.26840258e-04,
#        6.22710949e-04, 6.54682961e-04, 5.52629303e-04, 4.23743086e-04,
#        3.85015304e-04, 6.26771323e-04, 3.54381599e-04, 4.84144712e-04,
#        7.87491285e-04, 4.46171688e-04, 5.71555394e-04, 7.68225066e-04,
#        8.24665699e-04, 6.42878473e-04, 4.68273815e-04, 6.71488774e-04,
#        8.01597128e-04, 6.66920729e-04, 6.23216504e-04, 5.13649858e-04,
#        7.04526420e-04, 6.96251986e-04, 4.06065018e-04, 5.52125714e-04,
#        6.82408504e-04, 6.23637331e-04, 3.92028468e-04, 5.27924007e-04,
#        4.88002275e-04, 5.41855623e-04, 5.05489944e-04, 4.82457892e-04,
#        6.63443283e-04, 2.34877759e-04, 6.50555054e-04, 6.19815070e-04,
#        7.40340957e-04, 6.32465411e-04, 8.40412420e-04, 8.47417038e-04,
#        4.83930090e-04, 5.92367532e-04, 9.70623474e-04, 7.87808171e-04,
#        4.66795976e-04, 5.17239735e-04, 5.46280807e-04, 8.39239360e-04,
#        5.06050190e-04, 4.96407461e-04, 6.82875177e-04, 8.31155558e-04,
#        4.07780288e-04, 7.60215428e-04, 8.48256230e-04, 7.79306455e-04,
#        8.86753367e-04, 8.81842565e-04, 4.53237883e-04, 5.44187306e-04,
#        4.90779143e-04, 9.30695384e-04, 6.68363826e-04, 6.23051404e-04,
#        5.81435725e-04, 6.67310034e-04, 7.93391085e-04, 3.39950213e-04,
#        7.97320427e-04, 7.88743095e-04, 6.03004502e-04, 4.02811319e-04,
#        4.25958685e-04, 5.77162620e-04, 3.22064061e-04, 8.84902382e-04,
#        7.65650607e-04, 4.37452466e-04, 6.50407602e-04, 5.25111850e-04,
#        2.87942587e-04, 4.57554389e-04, 7.71997594e-04, 6.15116474e-04,
#        8.23768667e-04, 4.69996829e-04, 5.49565643e-04, 2.08976362e-04,
#        6.10852242e-04, 7.33345079e-04, 3.95949595e-04, 4.59458781e-04,
#        1.87567916e-04, 7.30873922e-04, 3.81677502e-04, 2.45479258e-04,
#        5.12311741e-04, 4.90434147e-04, 2.43227889e-04, 8.41362185e-04,
#        8.46831737e-04, 3.51417131e-04, 4.82613876e-04, 3.69811875e-04,
#        5.86892970e-04, 3.42583302e-04, 5.90260180e-04, 4.22870943e-04,
#        4.58266931e-04, 7.24549780e-04, 5.97634796e-04, 6.18545616e-04,
#        3.46985523e-04, 6.56567715e-04, 7.18401824e-04, 3.55914808e-04,
#        6.08232145e-04, 4.04619683e-04, 4.91383990e-04, 6.29618083e-04,
#        2.87817116e-04, 6.51219226e-05, 7.19014905e-04, 4.63578854e-04,
#        2.42790649e-04, 5.21845496e-04, 8.95150177e-04, 4.37673477e-04,
#        5.66282856e-04, 5.98039471e-04, 3.77172595e-04, 4.63341397e-04,
#        3.09932091e-04, 6.23955214e-04, 8.49544782e-04, 7.37659916e-04,
#        4.47368675e-04, 6.56733453e-04, 4.22265429e-04, 9.14624926e-04,
#        5.69376480e-04, 3.54053749e-04, 5.11824546e-04, 7.14550556e-04,
#        8.04014295e-04, 4.43298406e-04, 7.46209332e-04, 7.16986049e-04,
#        7.13423425e-04, 7.75746518e-04, 9.78757325e-04, 6.44771141e-04,
#        5.26843428e-04, 6.74977971e-04, 3.94263100e-04, 2.28429993e-04,
#        6.21392236e-04, 5.31799116e-04, 7.23310003e-04, 7.32476451e-04,
#        8.68232487e-04, 4.99694120e-04, 4.61776575e-04, 7.61727778e-04,
#        7.59101898e-04, 6.29647285e-04, 5.26986387e-04, 7.50064636e-04,
#        5.58863947e-04, 7.06237124e-04, 6.06614301e-04, 4.01499781e-04,
#        5.89187277e-04, 9.00129443e-04, 5.77009643e-04, 7.61283536e-04,
#        5.90145069e-04, 4.86080227e-04, 5.08944342e-04, 3.23417621e-04,
#        3.01223915e-04, 2.56366246e-04, 7.01631630e-04, 6.08744758e-04,
#        8.65071120e-04, 5.26297292e-04, 5.96030233e-04, 3.02656564e-04,
#        7.73287462e-04, 5.45522964e-04, 8.13108256e-04, 7.80333810e-04,
#        4.65154991e-04, 6.70453406e-04, 6.17416135e-04, 5.30910720e-04,
#        2.59457629e-05, 4.45395616e-04, 5.26817223e-04, 4.25082415e-04,
#        5.70924674e-04, 7.10588619e-04, 5.03922652e-04, 5.26526264e-04,
#        7.09982874e-04, 3.25854789e-04, 5.91198154e-04, 3.81530438e-04,
#        6.69633682e-04, 3.95836977e-04, 3.74707770e-04, 8.55027873e-04,
#        1.00288985e-03, 5.96379258e-04, 5.48416907e-04, 5.55631036e-04,
#        5.46296404e-04, 5.89515649e-04, 5.35777543e-04, 9.70934324e-04,
#        6.25759210e-04, 6.30765697e-04, 6.02250325e-04, 5.00414728e-04,
#        6.66623829e-04, 4.79571262e-04, 4.67831484e-04, 6.34943498e-04,
#        7.00627962e-04, 3.78368871e-04, 6.25295171e-04, 3.33241187e-04,
#        4.81793111e-04, 2.75462112e-04, 7.14521356e-04, 2.77197817e-04,
#        5.50874595e-04, 7.57929537e-04, 5.65910922e-04, 4.95379577e-04,
#        6.64690099e-04, 6.33315654e-04, 3.96079114e-04, 7.23852324e-04,
#        7.43031406e-04, 2.98432353e-04, 5.93519101e-04, 5.73216743e-04,
#        8.67575930e-04, 8.59550469e-04, 2.21215934e-04, 6.90672328e-04,
#        6.29653934e-04, 3.36162455e-04, 7.12679647e-04, 8.45562986e-04,
#        8.21349162e-04, 5.30231324e-04, 5.41740183e-04, 5.37126744e-04,
#        6.18336549e-04, 4.80929465e-04, 7.02903413e-04, 7.05746040e-04,
#        4.43458878e-04, 4.70533409e-04, 3.89780149e-04, 4.17020525e-04,
#        3.22456174e-04, 7.35437013e-04, 3.60737873e-04, 4.97929752e-04,
#        7.37239841e-04, 6.04074729e-04, 6.14274828e-04, 6.54409956e-04,
#        4.96670716e-04, 7.77098266e-04, 7.40414738e-04, 6.39867559e-04,
#        3.86324009e-04, 5.97819972e-04, 1.04097512e-04, 6.85476344e-04,
#        6.88784123e-04, 4.86397611e-04, 8.92243313e-04, 4.43515789e-04,
#        7.24415533e-04, 8.28133677e-04, 5.32789095e-04, 6.28579359e-04,
#        5.13770447e-04, 8.39875935e-04, 8.30836436e-04, 3.96948083e-04,
#        8.51096924e-04, 3.88771321e-04, 7.77333770e-04, 9.11569014e-04,
#        5.73161130e-04, 5.21258009e-04, 3.59043442e-04, 9.56614462e-04,
#        6.90472692e-04, 5.41198261e-04, 2.97017945e-04, 6.33190355e-04,
#        8.25151191e-04, 8.33319100e-04, 4.87989417e-04, 8.70980762e-04,
#        6.06520697e-04, 8.36301184e-04, 5.23827140e-04, 6.58108619e-04,
#        7.01345264e-04, 1.04600336e-03, 5.91274706e-04, 7.37571926e-04,
#        6.77052854e-04, 1.86330492e-04, 7.16365491e-04, 5.33101243e-04,
#        5.54195831e-04, 6.81857438e-04, 3.86557333e-04, 4.88341765e-04,
#        8.07643294e-04, 5.92066231e-04, 5.71410795e-04, 4.80253499e-04,
#        4.19908450e-04, 7.14558404e-04, 7.12165124e-04, 7.95174966e-04,
#        5.32496451e-04, 4.35513799e-04, 7.17591454e-04, 6.95355720e-04,
#        5.08311991e-04, 3.99258811e-04, 1.02186308e-03, 1.04970200e-03,
#        7.72498005e-04, 5.85611686e-04, 6.64106265e-04, 9.35672195e-04,
#        5.16998522e-04, 7.76480232e-04, 5.90851973e-04, 6.03363922e-04,
#        4.57724499e-04, 8.94135843e-04, 6.95171158e-04, 7.42234857e-04,
#        6.70601193e-04, 6.70876064e-04, 4.15405545e-04, 5.37192303e-04,
#        7.14908851e-04, 6.50749692e-04, 3.28538654e-04, 8.03197599e-04,
#        3.43239429e-04, 8.24141974e-04, 5.08122040e-04, 7.42498125e-04,
#        5.90433793e-04, 5.55403644e-04, 5.20566440e-04, 7.25036806e-04,
#        6.95954832e-04, 5.69242021e-04, 9.67290234e-04, 4.53624099e-04,
#        6.37031701e-04, 6.24555361e-04, 4.43239708e-04, 6.29906224e-04,
#        3.20391950e-04, 7.12764974e-04, 7.65484911e-04, 4.95528923e-04,
#        6.17085889e-04, 1.33359404e-04, 1.10214126e-03, 2.16018414e-04,
#        5.74624369e-04, 5.66566855e-04, 5.86165282e-04, 3.51763348e-04,
#        6.52167501e-04, 5.45337694e-04, 3.43582909e-04, 6.22127273e-04,
#        1.31309100e-04, 8.72183566e-04, 7.83085560e-04, 7.36073440e-04,
#        7.56004252e-04, 6.54820105e-04, 5.66021339e-04, 3.72217405e-04,
#        8.83710509e-04, 7.52942442e-04, 8.25642976e-04, 6.69943865e-04,
#        7.88963432e-04, 3.17913628e-04, 5.43462035e-04, 3.71432437e-04,
#        6.16546525e-04, 8.43087190e-04, 5.53719963e-04, 8.28896942e-04,
#        2.91133046e-04, 8.67180676e-04, 7.36079836e-04, 5.65353263e-04,
#        6.04953591e-04, 8.22669056e-04, 4.12046460e-04, 7.82755683e-04,
#        5.91222033e-04, 8.51578811e-04, 5.12974481e-04, 2.64903883e-04,
#        7.10145953e-04, 4.16961815e-04, 4.31357592e-04, 4.95541768e-04,
#        6.67080025e-04, 5.26637776e-04, 3.19983345e-04, 3.34883441e-04,
#        4.80684462e-04, 7.80046848e-04, 6.68259629e-04, 5.75955232e-04,
#        6.19839370e-04, 4.02379689e-04, 5.52275349e-04, 5.51124565e-04,
#        4.51620377e-04, 6.83934044e-04, 5.03853381e-04, 7.64283811e-04,
#        8.75110455e-04, 7.53288748e-04, 8.97561495e-04, 6.75341945e-04,
#        5.14130754e-04, 5.06626118e-04, 4.67538705e-04, 6.33756252e-04,
#        3.55931292e-04, 5.00127941e-04, 2.58079127e-04, 1.13540542e-03,
#        7.58003176e-04, 3.50251012e-04, 3.92440648e-04, 2.33893794e-04,
#        4.91992179e-04, 1.40554681e-04, 5.42231043e-04, 5.64582614e-04,
#        6.44072925e-04, 3.22248278e-04, 5.80008681e-04, 5.85866750e-04,
#        6.07076523e-04, 1.21321718e-03, 7.23497142e-04, 2.28050278e-04,
#        6.81957128e-04, 5.48885585e-04, 7.86406248e-04, 5.36129984e-04,
#        8.41991997e-04, 4.07422262e-04, 6.14564537e-04, 5.96918588e-04,
#        6.31295426e-04, 5.70846525e-04, 6.41375435e-04, 6.48232338e-04,
#        4.45494509e-04, 7.65591248e-04, 5.34051976e-04, 5.42575005e-04,
#        3.12473184e-04, 8.24846287e-04, 3.20264463e-04, 6.29831045e-04,
#        6.95991281e-04, 2.12588876e-04, 5.65662455e-04, 7.20852696e-04,
#        4.59146940e-04, 3.08241388e-04, 1.80310412e-04, 8.35731625e-04])

# %%
#Variance covariance
cov_mat = daily_returns.cov()
cov_mat
# Out:
#           ABOT      ACPL      ADMM      AGIL      AGTL
# ABOT  0.000298  0.000076  0.000031  0.000059  0.000072
# ACPL  0.000076  0.000353  0.000020  0.000070  0.000068
# ADMM  0.000031  0.000020  0.000423 -0.000006  0.000062
# AGIL  0.000059  0.000070 -0.000006  0.000435  0.000105
# AGTL  0.000072  0.000068  0.000062  0.000105  0.000488

# %%
portfolio_risk = []
for one_port in range(weights.shape[0]):
    
    risk = np.sqrt(np.dot(weights.iloc[one_port,:],np.dot(cov_mat,weights_t.iloc[:,one_port])))
    
    portfolio_risk.append(risk)

# %%
plt.figure(figsize = (10,8))
plt.scatter(portfolio_risk, portfolio_return)
plt.xlabel("Portfolio Risk - Standard Deviation")
plt.ylabel("Portfolio Return")
plt.show()

# %%
#converting to a csv file
portfolio_risk = pd.DataFrame(portfolio_risk, columns = ["portfolio risk"])
portfolio_return = pd.DataFrame(portfolio_return, columns = ["portfolio return"])
random_portfolio = pd.concat([portfolio_return, portfolio_risk, weights], axis =1)
random_portfolio.to_csv("Random_Portfolios.csv")
